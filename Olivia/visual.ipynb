# %%
import matplotlib.pyplot as plt
import numpy as np
import utils
import glob

def visual_right_scale(pos, ax):
    max_range = np.array([pos[:, 0].max()-pos[:, 0].min(),
                          pos[:, 1].max()-pos[:, 1].min(),
                          pos[:, 2].max()-pos[:, 2].min()]).max() / 2.0

    mid_x = (pos[:, 0].max()+pos[:, 0].min()) * 0.5
    mid_y = (pos[:, 1].max()+pos[:, 1].min()) * 0.5
    mid_z = (pos[:, 2].max()+pos[:, 2].min()) * 0.5

    # make scale look equal
    ax.set_xlim(mid_x - max_range, mid_x + max_range)
    ax.set_ylim(mid_y - max_range, mid_y + max_range)
    ax.set_zlim(mid_z - max_range, mid_z + max_range)


def visualize_3d_boxes(corners3d, ax):
    '''
    corners3d: (N, 8, 3)
    '''
    for n in range(corners3d.shape[0]):
        b = corners3d[n]  # (8, 3)

        for k in range(0, 4):
            i, j = k, (k + 1) % 4
            ax.plot([b[i, 0], b[j, 0]], [b[i, 1], b[j, 1]], [b[i, 2], b[j, 2]],
                    color='r')

            i, j = k + 4, (k + 1) % 4 + 4
            ax.plot([b[i, 0], b[j, 0]], [b[i, 1], b[j, 1]], [b[i, 2], b[j, 2]],
                    color='r')

            i, j = k, k + 4
            ax.plot([b[i, 0], b[j, 0]], [b[i, 1], b[j, 1]], [b[i, 2], b[j, 2]],
                    color='r')
    return
# Out:
# Jupyter environment detected. Enabling Open3D WebVisualizer.
# [Open3D INFO] WebRTC GUI backend enabled.
# [Open3D INFO] WebRTCWindowSystem: HTTP handshake server disabled.

# %%
#%matplotlib widget

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

pts = np.load("objdet/pts_769.20220829_184801.1661792344072243000.npy").reshape(-1, 3)
bbox = np.load("objdet/bbox_769.20220829_184801.1661792344072243000.npy").reshape(-1, 7)

corners3d = utils.boxes_to_corners_3d(bbox)

ax.scatter(pts[:, 0], pts[:, 1], pts[:, 2], s=5, c='g', lw=0, alpha=1)
visualize_3d_boxes(corners3d, ax)

visual_right_scale(corners3d.reshape(-1, 3), ax)
ax.title.set_text("Car")
ax.view_init(elev=120., azim=-90)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
plt.show()

# %%
import open3d as o3d
import numpy as np

# Load data
pcd = o3d.io.read_point_cloud("objdet/1661792344072243000.pcd")

boxes = np.load("objdet/corners_769.20220829_184801.1661792344072243000.npy")
#boxes = np.load("objdet/769.20220829_184801.1661792344072243000.npy")
#boxes = np.load("objdet/1.20220829_184801.1661792364172818000.npy")

box = o3d.geometry.OrientedBoundingBox.create_from_points(o3d.utility.Vector3dVector(boxes))
box.color = [1, 0, 0]

o3d.visualization.draw_geometries([pcd, box],
                                  zoom=1,
                                  front=[-1, 0, 0],
                                  lookat=boxes[-1],
                                  up=[0, 0, 1])
